# %% [markdown]
# # QADIR BUX
# ## DAY 2

# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("d:\DATANEW.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\1444696956.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv("d:\DATANEW.csv")

# %%
df
# Out:
#        Brand      Model            Color Memory Storage  Rating  \
# 0       OPPO        A53  Moonlight Black   4 GB   64 GB     4.5
# 1       OPPO        A53       Mint Cream   4 GB   64 GB     4.5
# 2       OPPO        A53  Moonlight Black   6 GB  128 GB     4.3
# 3       OPPO        A53       Mint Cream   6 GB  128 GB     4.3
# 4       OPPO        A53   Electric Black   4 GB   64 GB     4.5
# ...      ...        ...              ...    ...     ...     ...
# 2642  Xiaomi  Redmi Y3          Bold Red   4 GB   64 GB     4.3
# 2643  Xiaomi  Redmi Y3      Elegant Blue   3 GB   32 GB     4.3
# 2644  Xiaomi  Redmi Y3      Elegant Blue   4 GB   64 GB     4.2
# 2645  Xiaomi  Redmi Y3       Prime Black   3 GB   32 GB     4.2
# 2646  Xiaomi  Redmi Y3       Prime Black   4 GB   64 GB     4.3
#
#       Selling Price  Original Price
# 0           11990.0         15990.0
# 1           11990.0         15990.0
# 2           13990.0         17990.0
# 3           13990.0         17990.0
# 4           11990.0         15990.0
# ...             ...             ...
# 2642        12999.0         13999.0
# 2643         9450.0             NaN
# 2644        12999.0             NaN
# 2645         9950.0             NaN
# 2646        12499.0         13999.0
#
# [2647 rows x 8 columns]

# %%
df.head()
# Out:
#   Brand Model            Color Memory Storage  Rating  Selling Price  \
# 0  OPPO   A53  Moonlight Black   4 GB   64 GB     4.5        11990.0
# 1  OPPO   A53       Mint Cream   4 GB   64 GB     4.5        11990.0
# 2  OPPO   A53  Moonlight Black   6 GB  128 GB     4.3        13990.0
# 3  OPPO   A53       Mint Cream   6 GB  128 GB     4.3        13990.0
# 4  OPPO   A53   Electric Black   4 GB   64 GB     4.5        11990.0
#
#    Original Price
# 0         15990.0
# 1         15990.0
# 2         17990.0
# 3         17990.0
# 4         15990.0

# %%
df.shape
# Out:
# (2647, 8)

# %%
df.isnull().sum()
# Out:
# Brand                0
# Model                2
# Color              142
# Memory              42
# Storage             79
# Rating               0
# Selling Price        3
# Original Price    1678
# dtype: int64

# %%
percentage_of_null = (df.isnull().sum()/len(df))*100
percentage_of_null
# Out:
# Brand              0.000000
# Model              0.075557
# Color              5.364564
# Memory             1.586702
# Storage            2.984511
# Rating             0.000000
# Selling Price      0.113336
# Original Price    63.392520
# dtype: float64

# %%
df.dropna(subset= ["Model", "Memory", "Selling Price"], inplace = True)
df.isnull().sum()
# Out:
# Brand                0
# Model                0
# Color              117
# Memory               0
# Storage             60
# Rating               0
# Selling Price        0
# Original Price    1636
# dtype: int64

# %%
df.shape
# Out:
# (2600, 8)

# %%
(2600/2647)*100
# Out:
# 98.22440498677749

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2600 entries, 0 to 2646
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           2600 non-null   object
#  1   Model           2600 non-null   object
#  2   Color           2483 non-null   object
#  3   Memory          2600 non-null   object
#  4   Storage         2540 non-null   object
#  5   Rating          2600 non-null   float64
#  6   Selling Price   2600 non-null   float64
#  7   Original Price  964 non-null    float64
# dtypes: float64(3), object(5)
# memory usage: 182.8+ KB

# %%
df["Storage"].unique()
# Out:
# array(['64 GB', '128 GB', '32 GB', '256 GB', '16 GB', '8 GB', '64GB GB',
#        '4 GB', '512 GB', nan, '16 MB', '128 MB', '4 MB', '48 MB', '8 MB',
#        'Expandable Upto 32 GB', 'Expandable Upto 16 GB', '10 MB',
#        '256 MB', '140 MB', '64 MB', '1 TB', '32GB', '2.27 MB', '2 MB',
#        '153 MB', '512 MB', '2.3 MB', '1 MB', '0 MB', '100 MB'],
#       dtype=object)

# %%
df["Storage"].replace("Expandable Upto 32 GB", "32", inplace=True)
df["Storage"].replace("Expandable Upto 16 GB", "16", inplace=True)
df["Storage"].replace("64GB GB", "64", inplace=True)
df["Storage"].replace("32GB", "32", inplace=True)

df["Storage"].replace("4 GB", "4", inplace=True)
df["Storage"].replace("8 GB", "8", inplace=True)
df["Storage"].replace("16 GB", "16", inplace=True)
df["Storage"].replace("32 GB", "32", inplace=True)
df["Storage"].replace("64 GB", "64", inplace=True)
df["Storage"].replace("128 GB", "128", inplace=True)
df["Storage"].replace("256 GB", "256", inplace=True)
df["Storage"].replace("512 GB", "512", inplace=True)

df["Storage"].replace("1 TB", "1024", inplace=True)
df["Storage"].replace("16 MB", "0.015", inplace=True)
df["Storage"].replace("128 MB", "0.125", inplace=True)
df["Storage"].replace("4 MB", "0.003", inplace=True)
df["Storage"].replace("48 MB", "0.046", inplace=True)
df["Storage"].replace("8 MB", "0.007", inplace=True)
df["Storage"].replace("10 MB", "0.009", inplace=True)
df["Storage"].replace("256 MB", "0.25", inplace=True)
df["Storage"].replace("140 MB", "0.136", inplace=True)
df["Storage"].replace("64 MB", "0.062", inplace=True)
df["Storage"].replace("2.27 MB", "0.002", inplace=True)
df["Storage"].replace("2 MB", "0.001", inplace=True)
df["Storage"].replace("153 MB", "0.149", inplace=True)
df["Storage"].replace("512 MB", "0.5", inplace=True)
df["Storage"].replace("2.3 MB", "0.002", inplace=True)
df["Storage"].replace("1 MB", "0", inplace=True)
df["Storage"].replace("0 MB", "0", inplace=True)
df["Storage"].replace("100 MB", "0.097", inplace=True)
# Out:
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("Expandable Upto 32 GB", "32", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("Expandable Upto 16 GB", "16", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("64GB GB", "64", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("32GB", "32", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("4 GB", "4", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("8 GB", "8", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("16 GB", "16", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("32 GB", "32", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("64 GB", "64", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("128 GB", "128", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("256 GB", "256", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("512 GB", "512", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("1 TB", "1024", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("16 MB", "0.015", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("128 MB", "0.125", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("4 MB", "0.003", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("48 MB", "0.046", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("8 MB", "0.007", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("10 MB", "0.009", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("256 MB", "0.25", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("140 MB", "0.136", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("64 MB", "0.062", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:25: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("2.27 MB", "0.002", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:26: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("2 MB", "0.001", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:27: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("153 MB", "0.149", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:28: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("512 MB", "0.5", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("2.3 MB", "0.002", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:30: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("1 MB", "0", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:31: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("0 MB", "0", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3914664226.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Storage"].replace("100 MB", "0.097", inplace=True)

# %%
df["Storage"].unique()
# Out:
# array(['64', '128', '32', '256', '16', '8', '4', '512', nan, '0.015',
#        '0.125', '0.003', '0.046', '0.007', '0.009', '0.25', '0.136',
#        '0.062', '1024', '0.002', '0.001', '0.149', '0.5', '0', '0.097'],
#       dtype=object)

# %%
df.rename(columns = {"Storage": "StorageInGB"}, inplace = True)

# %%
df
# Out:
#        Brand      Model            Color Memory StorageInGB  Rating  \
# 0       OPPO        A53  Moonlight Black   4 GB          64     4.5
# 1       OPPO        A53       Mint Cream   4 GB          64     4.5
# 2       OPPO        A53  Moonlight Black   6 GB         128     4.3
# 3       OPPO        A53       Mint Cream   6 GB         128     4.3
# 4       OPPO        A53   Electric Black   4 GB          64     4.5
# ...      ...        ...              ...    ...         ...     ...
# 2642  Xiaomi  Redmi Y3          Bold Red   4 GB          64     4.3
# 2643  Xiaomi  Redmi Y3      Elegant Blue   3 GB          32     4.3
# 2644  Xiaomi  Redmi Y3      Elegant Blue   4 GB          64     4.2
# 2645  Xiaomi  Redmi Y3       Prime Black   3 GB          32     4.2
# 2646  Xiaomi  Redmi Y3       Prime Black   4 GB          64     4.3
#
#       Selling Price  Original Price
# 0           11990.0         15990.0
# 1           11990.0         15990.0
# 2           13990.0         17990.0
# 3           13990.0         17990.0
# 4           11990.0         15990.0
# ...             ...             ...
# 2642        12999.0         13999.0
# 2643         9450.0             NaN
# 2644        12999.0             NaN
# 2645         9950.0             NaN
# 2646        12499.0         13999.0
#
# [2600 rows x 8 columns]

# %%
mode = df["StorageInGB"].mode()[0]

df["StorageInGB"].fillna(mode, inplace = True)
df.isnull().sum()
# Out:
# Brand                0
# Model                0
# Color              117
# Memory               0
# StorageInGB          0
# Rating               0
# Selling Price        0
# Original Price    1636
# dtype: int64

# %%
df["StorageInGB"].unique()
# Out:
# array(['64', '128', '32', '256', '16', '8', '4', '512', '0.015', '0.125',
#        '0.003', '0.046', '0.007', '0.009', '0.25', '0.136', '0.062',
#        '1024', '0.002', '0.001', '0.149', '0.5', '0', '0.097'],
#       dtype=object)

# %%
df["StorageInGB"] = df["StorageInGB"].astype(float)

# %%
import numpy as np

def detect_outliers_z_score(data, threshold=3):
    outliers = []
    mean = np.mean(data)
    std = np.std(data)
    for i in data:
        z_score = (i - mean) / std
        if np.abs(z_score) > threshold:
            outliers.append(i)
    return outliers

scor = detect_outliers_z_score(df["StorageInGB"])

scor
# Out:
# [512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  1024.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  1024.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  1024.0,
#  1024.0,
#  512.0,
#  1024.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  1024.0,
#  512.0,
#  512.0,
#  1024.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  1024.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  1024.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0,
#  512.0]

# %%
df = df[df["StorageInGB"] != 512]
df = df[df["StorageInGB"] != 1024]

# %%
df
# Out:
#        Brand      Model            Color Memory  StorageInGB  Rating  \
# 0       OPPO        A53  Moonlight Black   4 GB         64.0     4.5
# 1       OPPO        A53       Mint Cream   4 GB         64.0     4.5
# 2       OPPO        A53  Moonlight Black   6 GB        128.0     4.3
# 3       OPPO        A53       Mint Cream   6 GB        128.0     4.3
# 4       OPPO        A53   Electric Black   4 GB         64.0     4.5
# ...      ...        ...              ...    ...          ...     ...
# 2642  Xiaomi  Redmi Y3          Bold Red   4 GB         64.0     4.3
# 2643  Xiaomi  Redmi Y3      Elegant Blue   3 GB         32.0     4.3
# 2644  Xiaomi  Redmi Y3      Elegant Blue   4 GB         64.0     4.2
# 2645  Xiaomi  Redmi Y3       Prime Black   3 GB         32.0     4.2
# 2646  Xiaomi  Redmi Y3       Prime Black   4 GB         64.0     4.3
#
#       Selling Price  Original Price
# 0           11990.0         15990.0
# 1           11990.0         15990.0
# 2           13990.0         17990.0
# 3           13990.0         17990.0
# 4           11990.0         15990.0
# ...             ...             ...
# 2642        12999.0         13999.0
# 2643         9450.0             NaN
# 2644        12999.0             NaN
# 2645         9950.0             NaN
# 2646        12499.0         13999.0
#
# [2537 rows x 8 columns]

# %%
sns.boxplot(df["StorageInGB"])
plt.show()

# %%
df.isnull().sum()
# Out:
# Brand                0
# Model                0
# Color              117
# Memory               0
# StorageInGB          0
# Rating               0
# Selling Price        0
# Original Price    1579
# dtype: int64

# %%
df["Color"].nunique()
# Out:
# 529

# %%
df["Color"] = df["Color"].str.upper()

# %%
df
# Out:
#        Brand      Model            Color Memory  StorageInGB  Rating  \
# 0       OPPO        A53  MOONLIGHT BLACK   4 GB         64.0     4.5
# 1       OPPO        A53       MINT CREAM   4 GB         64.0     4.5
# 2       OPPO        A53  MOONLIGHT BLACK   6 GB        128.0     4.3
# 3       OPPO        A53       MINT CREAM   6 GB        128.0     4.3
# 4       OPPO        A53   ELECTRIC BLACK   4 GB         64.0     4.5
# ...      ...        ...              ...    ...          ...     ...
# 2642  Xiaomi  Redmi Y3          BOLD RED   4 GB         64.0     4.3
# 2643  Xiaomi  Redmi Y3      ELEGANT BLUE   3 GB         32.0     4.3
# 2644  Xiaomi  Redmi Y3      ELEGANT BLUE   4 GB         64.0     4.2
# 2645  Xiaomi  Redmi Y3       PRIME BLACK   3 GB         32.0     4.2
# 2646  Xiaomi  Redmi Y3       PRIME BLACK   4 GB         64.0     4.3
#
#       Selling Price  Original Price
# 0           11990.0         15990.0
# 1           11990.0         15990.0
# 2           13990.0         17990.0
# 3           13990.0         17990.0
# 4           11990.0         15990.0
# ...             ...             ...
# 2642        12999.0         13999.0
# 2643         9450.0             NaN
# 2644        12999.0             NaN
# 2645         9950.0             NaN
# 2646        12499.0         13999.0
#
# [2537 rows x 8 columns]

# %%
df["Color"].replace("grey / silver",  "silver grey", inplace=True)
df["Color"].replace("grey/dark grey", "dark grey", inplace=True)
df["Color"].replace("grey / dark grey", "dark grey", inplace=True)
df["Color"].replace("grey/graphite grey", "graphite grey", inplace=True)
df["Color"].replace("grey / graphite grey", "graphite grey", inplace=True)
df["Color"].replace("grey/black", "grey & black", inplace=True)
df["Color"].replace("grey/flash gray", "flash grey", inplace=True)
df["Color"].replace("lunar gray", "lunar grey", inplace=True)
df["Color"].replace("kind of grey", "grey", inplace=True)
df["Color"].replace("aurora gray", "aurora grey", inplace=True)
df["Color"].replace("gray", "grey", inplace=True)
df["Color"].replace("smokey gray", "smokey grey", inplace=True)
df["Color"].replace("metallic gray", "metallic grey", inplace=True)
df["Color"].replace("phantom gray", "phantom grey", inplace=True)
df["Color"].replace("cosmic gray", "cosmic grey", inplace=True)
df["Color"].replace("dark gray", "dark grey", inplace=True)
df["Color"].replace("charcoal gray", "charcoal grey", inplace=True)
df["Color"].replace("titan gray", "titan grey", inplace=True)
df["Color"].replace("space gray", "space grey", inplace=True)


df["Color"].replace("blue mb", "blue", inplace = True)
df["Color"].replace("so white", "white", inplace=True)
df["Color"].replace("so blue", "blue", inplace=True)
df["Color"].replace("that blue", "blue", inplace=True)
df["Color"].replace("that green", "green", inplace=True)
df["Color"].replace("that white", "white", inplace=True)
df["Color"].replace("black and gold", "black & gold", inplace=True)
df["Color"].replace("night | dark blue", "dark blue", inplace=True)
df["Color"].replace("dusk | purple", "dusk purple", inplace=True)
df["Color"].replace("blue&copper", "blue & copper", inplace=True)
df["Color"].replace("copper/black", "copper black", inplace=True)
df["Color"].replace("blue/copper", "blue & copper", inplace=True)
df["Color"].replace("black&blue", "black & blue", inplace=True)
df["Color"].replace("pewter / white", "pewter white", inplace=True)
df["Color"].replace("black/tuxedo black", "tuxedo black", inplace=True)
df["Color"].replace("more than white", "white", inplace=True)
df["Color"].replace(" tornado black", "tornado black", inplace=True)
df["Color"].replace("just black", "black", inplace=True)
df["Color"].replace("clearly white", "white", inplace=True)
df["Color"].replace("very silver", "silver", inplace=True)
df["Color"].replace("silver titan", "titan silver", inplace=True)
df["Color"].replace("pure white", "white", inplace=True)
df["Color"].replace("mostly blue", "blue", inplace=True)


# replacing ambiguous values with unknown
df["Color"].replace("not pink", "unknown", inplace=True)
df["Color"].replace("not just blue", "unknown", inplace=True)
df["Color"].replace("100 mb", "unknown", inplace=True)
df["Color"].replace("conrete", "unknown", inplace=True)
# Out:
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("grey / silver",  "silver grey", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("grey/dark grey", "dark grey", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("grey / dark grey", "dark grey", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("grey/graphite grey", "graphite grey", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("grey / graphite grey", "graphite grey", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("grey/black", "grey & black", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("grey/flash gray", "flash grey", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("lunar gray", "lunar grey", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("kind of grey", "grey", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("aurora gray", "aurora grey", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("gray", "grey", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("smokey gray", "smokey grey", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("metallic gray", "metallic grey", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("phantom gray", "phantom grey", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("cosmic gray", "cosmic grey", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("dark gray", "dark grey", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("charcoal gray", "charcoal grey", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("titan gray", "titan grey", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("space gray", "space grey", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("blue mb", "blue", inplace = True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("so white", "white", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("so blue", "blue", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:25: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("that blue", "blue", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:26: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("that green", "green", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:27: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("that white", "white", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:28: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("black and gold", "black & gold", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("night | dark blue", "dark blue", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:30: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("dusk | purple", "dusk purple", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:31: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("blue&copper", "blue & copper", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("copper/black", "copper black", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:33: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("blue/copper", "blue & copper", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("black&blue", "black & blue", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:35: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("pewter / white", "pewter white", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("black/tuxedo black", "tuxedo black", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:37: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("more than white", "white", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:38: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace(" tornado black", "tornado black", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:39: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("just black", "black", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:40: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("clearly white", "white", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:41: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("very silver", "silver", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:42: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("silver titan", "titan silver", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:43: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("pure white", "white", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:44: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("mostly blue", "blue", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:48: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("not pink", "unknown", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:49: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("not just blue", "unknown", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("100 mb", "unknown", inplace=True)
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\622137469.py:51: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].replace("conrete", "unknown", inplace=True)

# %%
df["Color"].nunique()
# Out:
# 507

# %%
df = df[df["Color"] != "unknown"]

# %%
df
# Out:
#        Brand      Model            Color Memory  StorageInGB  Rating  \
# 0       OPPO        A53  MOONLIGHT BLACK   4 GB         64.0     4.5
# 1       OPPO        A53       MINT CREAM   4 GB         64.0     4.5
# 2       OPPO        A53  MOONLIGHT BLACK   6 GB        128.0     4.3
# 3       OPPO        A53       MINT CREAM   6 GB        128.0     4.3
# 4       OPPO        A53   ELECTRIC BLACK   4 GB         64.0     4.5
# ...      ...        ...              ...    ...          ...     ...
# 2642  Xiaomi  Redmi Y3          BOLD RED   4 GB         64.0     4.3
# 2643  Xiaomi  Redmi Y3      ELEGANT BLUE   3 GB         32.0     4.3
# 2644  Xiaomi  Redmi Y3      ELEGANT BLUE   4 GB         64.0     4.2
# 2645  Xiaomi  Redmi Y3       PRIME BLACK   3 GB         32.0     4.2
# 2646  Xiaomi  Redmi Y3       PRIME BLACK   4 GB         64.0     4.3
#
#       Selling Price  Original Price
# 0           11990.0         15990.0
# 1           11990.0         15990.0
# 2           13990.0         17990.0
# 3           13990.0         17990.0
# 4           11990.0         15990.0
# ...             ...             ...
# 2642        12999.0         13999.0
# 2643         9450.0             NaN
# 2644        12999.0             NaN
# 2645         9950.0             NaN
# 2646        12499.0         13999.0
#
# [2537 rows x 8 columns]

# %%
df["Color"].fillna(df["Color"].mode()[0], inplace=True)
df
# Out:
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\3689536219.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Color"].fillna(df["Color"].mode()[0], inplace=True)
#        Brand      Model            Color Memory  StorageInGB  Rating  \
# 0       OPPO        A53  MOONLIGHT BLACK   4 GB         64.0     4.5
# 1       OPPO        A53       MINT CREAM   4 GB         64.0     4.5
# 2       OPPO        A53  MOONLIGHT BLACK   6 GB        128.0     4.3
# 3       OPPO        A53       MINT CREAM   6 GB        128.0     4.3
# 4       OPPO        A53   ELECTRIC BLACK   4 GB         64.0     4.5
# ...      ...        ...              ...    ...          ...     ...
# 2642  Xiaomi  Redmi Y3          BOLD RED   4 GB         64.0     4.3
# 2643  Xiaomi  Redmi Y3      ELEGANT BLUE   3 GB         32.0     4.3
# 2644  Xiaomi  Redmi Y3      ELEGANT BLUE   4 GB         64.0     4.2
# 2645  Xiaomi  Redmi Y3       PRIME BLACK   3 GB         32.0     4.2
# 2646  Xiaomi  Redmi Y3       PRIME BLACK   4 GB         64.0     4.3
#
#       Selling Price  Original Price
# 0           11990.0         15990.0
# 1           11990.0         15990.0
# 2           13990.0         17990.0
# 3           13990.0         17990.0
# 4           11990.0         15990.0
# ...             ...             ...
# 2642        12999.0         13999.0
# 2643         9450.0             NaN
# 2644        12999.0             NaN
# 2645         9950.0             NaN
# 2646        12499.0         13999.0
#
# [2537 rows x 8 columns]

# %%
df["Original Price"].fillna(df["Original Price"].mean(), inplace = True)
# Out:
# C:\Users\deLL\AppData\Local\Temp\ipykernel_5772\1559490116.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Original Price"].fillna(df["Original Price"].mean(), inplace = True)

# %%
df.isnull().sum()
# Out:
# Brand             0
# Model             0
# Color             0
# Memory            0
# StorageInGB       0
# Rating            0
# Selling Price     0
# Original Price    0
# dtype: int64
